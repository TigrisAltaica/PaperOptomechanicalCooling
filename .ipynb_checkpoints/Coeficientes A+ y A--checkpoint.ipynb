# %% [markdown]
# El objetivo es calcular los coeficientes A+ y A- en base a los valores de las distintas frecuencias involucradas y del detuning debido al laser. Defino una función para calcular G y otra que calcula A+ y A- en base a G
#
# $$G(\nu,\omega,\lambda)=\frac{-\chi^2 \alpha^2}{\lambda + i\nu_0} + i\epsilon C $$,
#
# en particular me interesa conocer el valor de G con y sin la corrección.
#
# $$C=\frac{(\lambda+i\nu_0)^2 - \omega^2}{((\lambda+i\nu_0)^2 + \omega^2)^2} $$
#
# Programo una función G y una función G más la corrección. $\chi$ y $\alpha$ se definen como constantes globales. Se trabaja con $\frac{\delta}{\nu_0} = a$ como la variable, haciendo la sustitución se llega a que la corrección es
#
#
# $$C=\frac{(-k+i\nu_0(a+1))^2 - \omega^2}{((-k+i\nu_0(a+1))^2 + \omega^2)^2} $$
#
# y se toma un rango de $a \in [-2,2]$ para los calculos. Todos los parámetros se definen en terminos de $\nu_0$

# %%
 ENV["PYTHON"]="pythoncommand"
    Pkg.build("PyCall")
# Out:
#   Building Conda ─→ `~/.julia/packages/Conda/m7vem/deps/build.log`
#   Building PyCall → `~/.julia/packages/PyCall/rUul9/deps/build.log`
# ┌ Error: Error building `PyCall`:
# │ ┌ Info: No system-wide Python was found; got the following error:
# │ │ Base.IOError("could not spawn setenv(`pythoncommand -c \"import distutils.sysconfig; print(distutils.sysconfig.get_config_var('VERSION'))\"`,[\"PATH=/usr/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/home/pablo/Downloads/julia-1.0.0-linux-x86_64/julia-1.0.0/bin\", \"TEXTDOMAIN=im-config\", \"DEFAULTS_PATH=/usr/share/gconf/ubuntu.default.path\", \"QT_ACCESSIBILITY=1\", \"DBUS_SESSION_BUS_ADDRESS=unix:path=/run/user/1000/bus\", \"XDG_SESSION_DESKTOP=ubuntu\", \"SSH_AGENT_PID=2310\", \"XDG_SESSION_TYPE=x11\", \"USER=pablo\", \"QT_IM_MODULE=ibus\", \"LESSCLOSE=/usr/bin/lesspipe %s %s\", \"LC_NUMERIC=es_MX.UTF-8\", \"XDG_CONFIG_DIRS=/etc/xdg/xdg-ubuntu:/etc/xdg\", \"LC_TIME=es_MX.UTF-8\", \"LC_MEASUREMENT=es_MX.UTF-8\", \"GNOME_SHELL_SESSION_MODE=ubuntu\", \"USERNAME=pablo\", \"GDMSESSION=ubuntu\", \"LC_TELEPHONE=es_MX.UTF-8\", \"COLUMNS=80\", \"CLUTTER_IM_MODULE=xim\", \"DESKTOP_AUTOSTART_ID=10217bf26598606dbd15370253356933800000022140019\", \"XDG_DATA_DIRS=/usr/share/ubuntu:/usr/local/share:/usr/share:/var/lib/snapd/desktop\", \"LESSOPEN=| /usr/bin/lesspipe %s\", \"SHELL=/bin/bash\", \"XDG_SEAT=seat0\", \"XAUTHORITY=/run/user/1000/gdm/Xauthority\", \"XDG_MENU_PREFIX=gnome-\", \"GTK_MODULES=gail:atk-bridge\", \"GTK_IM_MODULE=ibus\", \"SESSION_MANAGER=local/pablo-HP-Pavilion-Power-Laptop-15-cb0xx:@/tmp/.ICE-unix/2214,unix/pablo-HP-Pavilion-Power-Laptop-15-cb0xx:/tmp/.ICE-unix/2214\", \"XMODIFIERS=@im=ibus\", \"LINES=30\", \"TERM=xterm-256color\", \"HOME=/home/pablo\", \"COLORTERM=truecolor\", \"PYTHONIOENCODING=UTF-8\", \"VTE_VERSION=5202\", \"PYTHON=pythoncommand\", \"IM_CONFIG_PHASE=2\", \"XDG_CURRENT_DESKTOP=ubuntu:GNOME\", \"LANG=en_US.UTF-8\", \"SHLVL=1\", \"GNOME_DESKTOP_SESSION_ID=this-is-deprecated\", \"LC_MONETARY=es_MX.UTF-8\", \"LOGNAME=pablo\", \"XDG_RUNTIME_DIR=/run/user/1000\", \"SSH_AUTH_SOCK=/run/user/1000/keyring/ssh\", \"DESKTOP_SESSION=ubuntu\", \"LC_PAPER=es_MX.UTF-8\", \"LC_ADDRESS=es_MX.UTF-8\", \"_=/usr/bin/jupyter\", \"GPG_AGENT_INFO=/run/user/1000/gnupg/S.gpg-agent:0:1\", \"GNOME_TERMINAL_SCREEN=/org/gnome/Terminal/screen/a26fa061_1e12_4587_97f3_9ca27a9df0a3\", \"GNOME_TERMINAL_SERVICE=:1.72\", \"PWD=/home/pablo\", \"DISPLAY=:1\", \"JPY_PARENT_PID=24555\", \"XDG_VTNR=2\", \"MANDATORY_PATH=/usr/share/gconf/ubuntu.mandatory.path\", \"LC_NAME=es_MX.UTF-8\", \"XDG_SESSION_ID=4\", \"TEXTDOMAINDIR=/usr/share/locale/\", \"LC_IDENTIFICATION=es_MX.UTF-8\", \"JULIA_LOAD_PATH=@:/tmp/tmpmQAlv6\", \"QT4_IM_MODULE=xim\", \"WINDOWPATH=2\", \"LS_COLORS=rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.Z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra= ...
# │ └ using the Python distribution in the Conda package
# │ [ Info: Downloading miniconda installer ...
# │ ERROR: LoadError: IOError: could not spawn `curl -g -L -f -o /home/pablo/.julia/packages/Conda/m7vem/deps/usr/installer.sh https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh`: no such file or directory (ENOENT)
# │ Stacktrace:
# │  [1] _jl_spawn(::String, ::Array{String,1}, ::Cmd, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:367
# │  [2] (::getfield(Base, Symbol("##495#496")){Cmd})(::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:509
# │  [3] setup_stdio(::getfield(Base, Symbol("##495#496")){Cmd}, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:490
# │  [4] #_spawn#494(::Nothing, ::Function, ::Cmd, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:508
# │  [5] _spawn at ./process.jl:504 [inlined]
# │  [6] #run#505(::Bool, ::Function, ::Cmd) at ./process.jl:652
# │  [7] run at ./process.jl:651 [inlined]
# │  [8] download(::String, ::String) at ./download.jl:48
# │  [9] macro expansion at ./logging.jl:311 [inlined]
# │  [10] _install_conda(::String, ::Bool) at /home/pablo/.julia/packages/Conda/m7vem/src/Conda.jl:146
# │  [11] _install_conda(::String) at /home/pablo/.julia/packages/Conda/m7vem/src/Conda.jl:145
# │  [12] runconda(::Cmd, ::String) at /home/pablo/.julia/packages/Conda/m7vem/src/Conda.jl:111
# │  [13] add at /home/pablo/.julia/packages/Conda/m7vem/src/Conda.jl:174 [inlined] (repeats 2 times)
# │  [14] top-level scope at logging.jl:312
# │  [15] top-level scope at /home/pablo/.julia/packages/PyCall/rUul9/deps/build.jl:196
# │  [16] include at ./boot.jl:317 [inlined]
# │  [17] include_relative(::Module, ::String) at ./loading.jl:1038
# │  [18] include(::Module, ::String) at ./sysimg.jl:29
# │  [19] include(::String) at ./client.jl:388
# │  [20] top-level scope at none:0
# │ in expression starting at /home/pablo/.julia/packages/PyCall/rUul9/deps/build.jl:170
# └ @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.0/Pkg/src/Operations.jl:1068

# %%
nu0=2500
m=round(Int,sqrt(.5*nu0))
chi = 1
alpha =1
k = .5*nu0 #kappa es el decaimiento de la cavidad
w = nu0/m;
ep=(m^2)/5 #El valor de epsilon

function Aminus(a,epsilon)
    k*chi*alpha/(k^2+nu0^2*(a+1)^2)+real(im*epsilon*((-k+im*nu0*(a+1))^2-4*w^2)/((-k+im*nu0*(a+1))^2+4*w^2)^2)
end

function Aplus(a,epsilon)
    k*chi*alpha/(k^2+nu0^2*(a-1)^2)+real(im*epsilon*((-k+im*nu0*(a-1))^2-4*w^2)/((-k+im*nu0*(a-1))^2+4*w^2)^2)
end
n=6
mesh =2^n
y=Vector(undef,2^(n+2)+1)
ye=Vector(undef,2^(n+2)+1)
x=Vector(undef,2^(n+2)+1)
temp=Vector(undef,2^(n+2)+1)
tempe=Vector(undef,2^(n+2)+1)
i=1

for a=-2:1/mesh:2
    y[i]=Aminus(a,0)
    ye[i]=Aplus(a,ep)
    temp[i]=Aplus(a,0)/(Aminus(a,0)-Aplus(a,0))
    tempe[i]=Aplus(a,ep)/(Aminus(a,ep)-Aplus(a,ep))
    x[i]=a
    i+=1
end

# %%
p = plots(x,ye)
xlabel("Delta/Frecuencia")
ylabel("A-")
title("Coeficiente A- con corrección")
grid("on")
# Out:
# UndefVarError: plots not defined
#
# Stacktrace:
#  [1] top-level scope at In[6]:1

# %%
l=70
p = plot(x[1:l],tempe[1:l],"-")
p1 = plot(x[1:l],temp[1:l],".")
xlabel(L"\frac{\delta}{\nu_0}")
ylabel("̣̣<m>")
title("Comparación de Temperatura")
grid("on")
# Out:
# ArgumentError: haskey of NULL PyObject
#
# Stacktrace:
#  [1] haskey(::PyCall.PyObject, ::String) at /home/pablo/.julia/packages/PyCall/rUul9/src/PyCall.jl:310
#  [2] #plot#85(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::Array{Any,1}, ::Vararg{Any,N} where N) at /home/pablo/.julia/packages/PyPlot/fZuOQ/src/PyPlot.jl:176
#  [3] plot(::Array{Any,1}, ::Vararg{Any,N} where N) at /home/pablo/.julia/packages/PyPlot/fZuOQ/src/PyPlot.jl:176
#  [4] top-level scope at In[46]:2

# %%
p = plot(x,tempe)
xlabel(L"\frac{\nu_0}{\delta}")
ylabel("m")
title("Temperatura con Corrección")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f21ca52b610>)

# %%
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#  Installed Loess ────────────────── v0.5.0
#  Installed DiffRules ────────────── v0.0.7
#  Installed LineSearches ─────────── v7.0.0
#  Installed PDMats ───────────────── v0.9.5
#  Installed DataStreams ──────────── v0.4.1
#  Installed Arpack ───────────────── v0.2.3
#  Installed DocStringExtensions ──── v0.5.0
#  Installed Gadfly ───────────────── v0.8.0
#  Installed Ratios ───────────────── v0.3.0
#  Installed AxisAlgorithms ───────── v0.3.0
#  Installed CodecZlib ────────────── v0.5.0
#  Installed Media ────────────────── v0.4.1
#  Installed IterTools ────────────── v1.0.0
#  Installed IndirectArrays ───────── v0.5.0
#  Installed URIParser ────────────── v0.4.0
#  Installed Optim ────────────────── v0.17.1
#  Installed ShowItLikeYouBuildIt ─── v0.2.0
#  Installed NLSolversBase ────────── v7.1.0
#  Installed CategoricalArrays ────── v0.3.13
#  Installed WeakRefStrings ───────── v0.5.3
#  Installed Calculus ─────────────── v0.4.1
#  Installed Hexagons ─────────────── v0.2.0
#  Installed KernelDensity ────────── v0.5.0
#  Installed ForwardDiff ──────────── v0.9.0
#  Installed Rmath ────────────────── v0.5.0
#  Installed CommonSubexpressions ─── v0.2.0
#  Installed OffsetArrays ─────────── v0.8.1
#  Installed DataFrames ───────────── v0.13.1
#  Installed Parameters ───────────── v0.10.1
#  Installed PositiveFactorizations ─ v0.2.1
#  Installed StatsFuns ────────────── v0.7.0
#  Installed Distributions ────────── v0.16.4
#  Installed FFTW ─────────────────── v0.2.4
#  Installed DiffResults ──────────── v0.0.3
#  Installed Distances ────────────── v0.7.3
#  Installed DiffEqDiffTools ──────── v0.6.0
#  Installed Interpolations ───────── v0.8.0
#  Installed AbstractFFTs ─────────── v0.3.2
#  Installed SpecialFunctions ─────── v0.7.0
#  Installed Juno ─────────────────── v0.5.3
#  Installed CoupledFields ────────── v0.1.0
#  Installed Compose ──────────────── v0.6.1
#  Installed WoodburyMatrices ─────── v0.4.1
#  Installed QuadGK ───────────────── v2.0.2
#  Installed BinDeps ──────────────── v0.8.10
#  Installed TranscodingStreams ───── v0.8.1
#  Installed OrderedCollections ───── v1.0.0
#  Installed DataArrays ───────────── v0.7.0
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [c91e804a] + Gadfly v0.8.0
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.3.2
#   [7d9fca2a] + Arpack v0.2.3
#   [13072b0f] + AxisAlgorithms v0.3.0
#   [9e28174c] + BinDeps v0.8.10
#   [49dc2e85] + Calculus v0.4.1
#   [324d7699] + CategoricalArrays v0.3.13
#   [944b1d66] + CodecZlib v0.5.0
#   [bbf7d656] + CommonSubexpressions v0.2.0
#   [a81c6b42] + Compose v0.6.1
#   [7ad07ef1] + CoupledFields v0.1.0
#   [0fe7c1db] + DataArrays v0.7.0
#   [a93c6f00] + DataFrames v0.13.1
#   [9a8bc11e] + DataStreams v0.4.1
#   [01453d9d] + DiffEqDiffTools v0.6.0
#   [163ba53b] + DiffResults v0.0.3
#   [b552c78f] + DiffRules v0.0.7
#   [b4f34e82] + Distances v0.7.3
#   [31c24e10] + Distributions v0.16.4
#   [ffbed154] + DocStringExtensions v0.5.0
#   [7a1cc6ca] + FFTW v0.2.4
#   [f6369f11] + ForwardDiff v0.9.0
#   [c91e804a] + Gadfly v0.8.0
#   [a1b4810d] + Hexagons v0.2.0
#   [9b13fd28] + IndirectArrays v0.5.0
#   [a98d9a8b] + Interpolations v0.8.0
#   [c8e1da08] + IterTools v1.0.0
#   [e5e0dc1b] + Juno v0.5.3
#   [5ab0869b] + KernelDensity v0.5.0
#   [d3d80556] + LineSearches v7.0.0
#   [4345ca2d] + Loess v0.5.0
#   [e89f7d12] + Media v0.4.1
#   [d41bc354] + NLSolversBase v7.1.0
#   [6fe1bfb0] + OffsetArrays v0.8.1
#   [429524aa] + Optim v0.17.1
#   [bac558e1] + OrderedCollections v1.0.0
#   [90014a1f] + PDMats v0.9.5
#   [d96e819e] + Parameters v0.10.1
#   [85a6dd25] + PositiveFactorizations v0.2.1
#   [1fd47b50] + QuadGK v2.0.2
#   [c84ed2f1] + Ratios v0.3.0
#   [79098fc4] + Rmath v0.5.0
#   [9966252f] + ShowItLikeYouBuildIt v0.2.0
#   [276daf66] + SpecialFunctions v0.7.0
#   [4c63d2b9] + StatsFuns v0.7.0
#   [3bb67fe8] + TranscodingStreams v0.8.1
#   [30578b45] + URIParser v0.4.0
#   [ea10d353] + WeakRefStrings v0.5.3
#   [efce3f68] + WoodburyMatrices v0.4.1
#   [9fa8497b] + Future
#   [9abbd945] + Profile
#   [4607b0f0] + SuiteSparse
#   Building Arpack ──────────→ `~/.julia/packages/Arpack/WP3ru/deps/build.log`
#   Building CodecZlib ───────→ `~/.julia/packages/CodecZlib/wwgbh/deps/build.log`
#   Building Rmath ───────────→ `~/.julia/packages/Rmath/Py9gH/deps/build.log`
#   Building FFTW ────────────→ `~/.julia/packages/FFTW/p7sLQ/deps/build.log`
#   Building SpecialFunctions → `~/.julia/packages/SpecialFunctions/KvXoO/deps/build.log`

# %%
using Plots

# %%
for i = 1:size(x,1)
println(tempe[i])
end
# Out:
# 0.14168329998218226
# 0.13912859896143895
# 0.13659587746198515
# 0.13408567211469455
# 0.1315985371421503
# 0.12913504509427443
# 0.12669578762237624
# 0.12428137629410697
# 0.12189244345200367
# 0.11952964311852264
# 0.11719365195070217
# 0.11488517024785745
# 0.1126049230160003
# 0.11035366109300002
# 0.10813216233885822
# 0.10594123289586939
# 0.10378170852388353
# 0.10165445601638862
# 0.09956037470368967
# 0.09750039805009876
# 0.09547549535276918
# 0.09348667355062905
# 0.09153497915280631
# 0.08962150029701915
# 0.08774736894964741
# 0.08591376326064462
# 0.08412191008812596
# 0.08237308770942425
# 0.08066862873769444
# 0.07900992326583238
# 0.0773984222626254
# 0.07583564124975913
# 0.07432316429265878
# 0.07286264834325276
# 0.07145582797872466
# 0.07010452058728794
# 0.06881063206008979
# 0.06757616305763034
# 0.06640321592964546
# 0.06529400237926236
# 0.06425085197533913
# 0.06327622163105733
# 0.06237270618169961
# 0.06154305020953522
# 0.06079016127799796
# 0.06011712474967059
# 0.05952722037139786
# 0.05902394081314065
# 0.058611012342575076
# 0.05829241780226407
# 0.05807242202771364
# 0.057955599800202935
# 0.05794686636599502
# 0.05805151047261915
# 0.05827522977437464
# 0.05862416834648515
# 0.059104955926857446
# 0.059724748385906884
# 0.0604912688214324
# 0.06141284860286331
# 0.06249846766488989
# 0.0637577933921786
# 0.06520121756028438
# 0.06683989101454031
# 0.06868575608375271
# 0.07075157713586766
# 0.07305097017601547
# 0.07559843294173789
# 0.07840937753582171
# 0.08150016821833513
# 0.0848881675184583
# 0.08859179428835331
# 0.09263059767812747
# 0.09702535124804011
# 0.10179817155332489
# 0.1069726655594091
# 0.11257411121159623
# 0.11862967545191083
# 0.12516867401923856
# 0.132222877568526
# 0.13982686908585215
# 0.14801845834368021
# 0.15683916031769765
# 0.1663347461561276
# 0.17655587754186639
# 0.18755883821887762
# 0.19940638019567858
# 0.21216870686367187
# 0.22592462121629034
# 0.2407628748613755
# 0.25678376305164224
# 0.2741010231684227
# 0.2928441098905191
# 0.3131609409319982
# 0.33522123452303665
# 0.35922059626169706
# 0.3853855621947593
# 0.4139798722225699
# 0.44531234083610927
# 0.4797468221913195
# 0.5177149508322858
# 0.5597326044349848
# 0.6064214220785752
# 0.6585372865882863
# 0.7170085495251883
# 0.7829881207105938
# 0.8579256652051229
# 0.9436695840774266
# 1.0426141699335931
# 1.1579171423345878
# 1.293830232538275
# 1.4562178556291765
# 1.6534017944062736
# 1.8975989338276085
# 2.207502194738637
# 2.613227177025464
# 3.1666105116274803
# 3.965100800259435
# 5.216075649595567
# 7.452738441477198
# 12.587977610956512
# 36.55186704444042
# -45.03824084406298
# -14.415117829943716
# -8.751458633147681
# -6.369338478666347
# -5.05853730437477
# -4.22978628487039
# -3.6590206640232967
# -3.2424121739785114
# -2.9252579467082747
# -2.6759995968204957
# -2.4751536834234
# -2.3100407115296853
# -2.17205353124432
# -2.055143920813411
# -1.954937398497727
# -1.8681917049245564
# -1.7924527498709104
# -1.725828830130161
# -1.6668382560084127
# -1.614303972503117
# -1.567279092215192
# -1.5249932541944065
# -1.4868133163064559
# -1.4522141032160285
# -1.4207563315681955
# -1.3920697386115257
# -1.3658400373913566
# -1.3417987228562172
# -1.3197150275315288
# -1.2993895159075401
# -1.2806489408858122
# -1.2633420814281622
# -1.247336349785241
# -1.2325150072900215
# -1.2187748650902919
# -1.206024374092379
# -1.194182029399321
# -1.1831750304894573
# -1.1729381506087886
# -1.1634127782892938
# -1.1545461012450555
# -1.1462904086449683
# -1.1386024922901117
# -1.1314431308157489
# -1.1247766439030578
# -1.1185705057837567
# -1.1127950091734224
# -1.1074229722697808
# -1.1024294826724454
# -1.097791673076092
# -1.0934885244030292
# -1.0895006927071906
# -1.085810356725973
# -1.0824010833996855
# -1.0792577090370015
# -1.0763662340919196
# -1.073713729744362
# -1.071288254652388
# -1.0690787803782147
# -1.067075124091989
# -1.0652678872362544
# -1.0636483989007552
# -1.062208662722804
# -1.0609413062045068
# -1.0598395314358953
# -1.058897066342327
# -1.0581081157426329
# -1.057467311714709
# -1.0569696630157472
# -1.0566105035874462
# -1.0563854404786168
# -1.0562903018193999
# -1.0563210857595933
# -1.0564739115130395
# -1.0567449738060266
# -1.0571305020893131
# -1.0576267258263732
# -1.058229847009695
# -1.0589360207882426
# -1.0597413447297221
# -1.0606418568186864
# -1.061633541841408
# -1.0627123453705571
# -1.0638741941763592
# -1.065115021590056
# -1.0664307961547725
# -1.0678175518306474
# -1.069271418074442
# -1.07078864827556
# -1.0723656452775132
# -1.073998983017234
# -1.0756854236432365
# -1.0774219297981962
# -1.0792056720476773
# -1.081034031686765
# -1.0829045993499
# -1.0848151699828534
# -1.0867637348119767
# -1.0887484709712607
# -1.090767729431687
# -1.0928200218301871
# -1.0949040067274616
# -1.0970184757441854
# -1.0991623399413253
# -1.101334616728375
# -1.1035344175074149
# -1.1057609361936447
# -1.1080134386957479
# -1.110291253392443
# -1.1125937626044833
# -1.1149203950332862
# -1.1172706191172375
# -1.1196439372432312
# -1.1220398807429999
# -1.1244580056000835
# -1.1268978887928744
# -1.129359125201169
# -1.1318413250073303
# -1.1343441115279278
# -1.1368671194170943
# -1.139409993188494
# -1.1419723860084379
# -1.1445539587181668
# -1.147154379048481
# -1.1497733209946897
# -1.1524104643242206
# -1.155065494193163
# -1.1577381008515264
# -1.1604279794200794
# -1.1631348297243556
# -1.165858356173748
# -1.168598267675662
# -1.1713542775764254
# -1.174126103622145
# -1.17691346793397

# %%
size(x,1)
# Out:
# 257
